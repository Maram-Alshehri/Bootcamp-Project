# %% [markdown]
# # Smartphone Recommendation system

# %% [markdown]
# The aim of the project is build a recommendation system using Machine Learning techniques to recommend mobile phones to a user.
#
#
# The  system was build based on  collaborative filtering methods the first one is  collaborative filtering model using SVD and the seconed is a collaborative filtering model using kNNWithMeans from surprise using Item based model.
# The bellow plot shows the result of each model based on RMSE
#
# ![plot.png](data:image/png;base64,...)
